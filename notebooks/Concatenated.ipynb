# %%
#point to lunar library locally
import sys

sys.path.append('/Users/oakley/Documents/GitHub/lunar')
from lunar.identify_glare import concatenate_and_cluster
from lunar import plot_days
from lunar import add_time

# %%
add_time('../data/smooth_22Jul2024.tsv', '2024-07-22 18:06:00', '../data/time_22Jul2024.tsv')
add_time('../data/smooth_23Jul2024.tsv', '2024-07-23 18:30:00', '../data/time_23Jul2024.tsv')
add_time('../data/smooth_24Jul2024.tsv', '2024-07-24 18:12:00', '../data/time_24Jul2024.tsv')
add_time('../data/smooth_25Jul2024.tsv', '2024-07-25 18:14:00', '../data/time_25Jul2024.tsv')
# Out:
# New file with absolute time column saved as ../data/time_22Jul2024.tsv
# New file with absolute time column saved as ../data/time_23Jul2024.tsv
# New file with absolute time column saved as ../data/time_24Jul2024.tsv
# New file with absolute time column saved as ../data/time_25Jul2024.tsv

# %%
concatenate_and_cluster('../data/time_2?Jul2024.tsv', 2, '../data/timePanama2024_k2.tsv')

# %%
plot_days('../data/timePanama2024_k2.tsv', x_axis='time')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plot_days('Panama2024_k2.tsv')

# %%
concatenate_and_cluster('smooth_2?Jul2024.tsv', 3, 'Panama2024_k3.tsv')

# %%
plot_days('Panama2024_k3.tsv')
